# %% [markdown]
# <a href="https://colab.research.google.com/github/fahadsultan09/2026-MT-Fahad-Sultan/blob/main/src/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import xml.etree.ElementTree as ET

url = "https://raw.githubusercontent.com/fahadsultan09/2026-MT-Fahad-Sultan/main/data//raw/Jabeur_All_hits_fixed_v3.xml"

response = requests.get(url)
xml_data = response.text
root = ET.fromstring(xml_data)

print(root)
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "/tmp/ipykernel_26846/1015627989.py", line 8, in <cell line: 0>
#     root = ET.fromstring(xml_data)
#
#   File "/usr/lib/python3.12/xml/etree/ElementTree.py", line 1335, in XML
#     parser.feed(text)
#
#   File "<string>", line unknown
# ParseError: syntax error: line 1, column 0
